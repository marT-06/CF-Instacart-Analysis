# %% [markdown]
# # Importing libraries

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Importing Data

# %%
# Turn a project folder path into a string

path = r'/Users/mart/Documents/06-2022 Instacart Basket Analysis'

# %%
# Import the "orders_products_merged.pkl"

df_ords_prods_merged = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))

# %%
df_ords_prods_merged.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   3139998      138            28          6                 11
# 1   1977647      138            30          6                 17
# 2    389851      709             2          0                 21
# 3    652770      764             1          3                 13
# 4   1813452      764             3          4                 17
#
#    days_since_prior_order  first_time_order  add_to_cart_order  reordered  \
# ...

# %%
# delete the column "eval_set", '_merge' and 'Check'

 df_ords_prods_merged = df_ords_prods_merged.drop(['eval_set','_merge','Check'], axis = 1)
# Out:
#   Input In [6]
#     df_ords_prods_merged = df_ords_prods_merged.drop(['eval_set','_merge','Check'], axis=1)
#     ^
# IndentationError: unexpected indent

# %%
df_ords_prods_merged.head()

# %%
df_ords_prods_merged.isnull().sum()
# Out:
# product_id                       0
# product_name                     0
# aisle_id                         0
# department_id                    0
# prices                           0
# order_id                         0
# user_id                          0
# order_number                     0
# order_dow                        0
# order_hour_of_day                0
# days_since_prior_order     2076096
# first_time_order                 0
# add_to_cart_order                0
# reordered                        0
# price_range_loc           21208222
# busiest_day                      0
# busiest_days                     0
# busiest_period_of_day            0
# dtype: int64

# %%
df_ords_prods_merged.shape
# Out:
# (32404859, 18)

# %%
# Create a subset of df_ords_prods_merged

df = df_ords_prods_merged[:1000000]

# %%
df.shape
# Out:
# (1000000, 18)

# %% [markdown]
# # If-Statements with User-Defined Functions

# %%
# Define a function

def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
# Apply a function

df['price_range'] = df.apply(price_label, axis=1)
# Out:
# /var/folders/s5/c1fyrk214ksgcxn10_b3csvr0000gn/T/ipykernel_4931/3842331271.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
# check the values in the "price_range"

df['price_range'].value_counts(dropna = False)
# Out:
# Mid-range product    652638
# Low-range product    338018
# High range             9344
# Name: price_range, dtype: int64

# %%
# return max value within the "prices" column

df['prices'].max()
# Out:
# 24.5

# %% [markdown]
# # If-Statements with the loc() Function

# %%
# create conditions for a subset

df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product     652638
# Low-range product     338018
# High-range product      9344
# Name: price_range_loc, dtype: int64

# %%
# create conditions for an entire df

df_ords_prods_merged.loc[df_ords_prods_merged['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df_ords_prods_merged.loc[(df_ords_prods_merged['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df_ords_prods_merged['price_range_loc'].value_counts(dropna = False)
# Out:
# NaN                   21208222
# Low-range product     10126321
# Mid-range product       652638
# High-range product      417678
# Name: price_range_loc, dtype: int64

# %% [markdown]
# # If- Statement with For-Loops

# %%
df_ords_prods_merged.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   3139998      138            28          6                 11
# 1   1977647      138            30          6                 17
# 2    389851      709             2          0                 21
# 3    652770      764             1          3                 13
# 4   1813452      764             3          4                 17
#
#    days_since_prior_order  first_time_order  add_to_cart_order  reordered  \
# ...

# %%
# find out on which day most orders take place

df_ords_prods_merged['order_dow' ].value_counts (dropna = False)
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: order_dow, dtype: int64

# %%
# create a list of how busy each day of the week is

result = []

for value in df_ords_prods_merged["order_dow"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Busiest day',
#  'Least busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
#create a new column within df_ords_prods_merged dataframe and set it equal to result

df_ords_prods_merged['busiest_day'] = result

# %%
df_ords_prods_merged['busiest_day'].value_counts(dropna = False)
# Out:
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: busiest_day, dtype: int64

# %% [markdown]
# # Task

# %% [markdown]
# * Suppose your clients have changed their minds about the labels you created in your “busiest_day” column. Now, they want “Busiest day” to become “Busiest days” (plural). This label should correspond with the two busiest days of the week as opposed to the single busiest day. At the same time, they’d also like to know the two slowest days. Create a new column for this using a suitable method.

# %%
# on which days most orders take place

df_ords_prods_merged['order_dow' ].value_counts (dropna = False)
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: order_dow, dtype: int64

# %%
# create a list of the two busiest days and the two slowest days of the week

result = []

for value in df_ords_prods_merged["order_dow"]:
  if value == 0 or value ==1:
    result.append("Busiest days")
  elif value == 3 or value == 4:
    result.append("Least busy days")
  else:
    result.append("Regularly busy days")

# %%
result
# Out:
# ['Regularly busy days',
#  'Regularly busy days',
#  'Busiest days',
#  'Least busy days',
#  'Least busy days',
#  'Busiest days',
#  'Regularly busy days',
#  'Least busy days',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy days',
#  'Least busy days',
#  'Least busy days',
#  'Regularly busy days',
#  'Least busy days',
#  'Regularly busy days',
#  'Regularly busy days',
#  'Regularly busy days',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Least busy days',
#  'Regularly busy days',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy days',
#  'Regularly busy days',
#  'Least busy days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Least busy days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Least busy days',
# ...

# %%
#create a new column within df_ords_prods_merged dataframe and set it equal to result

df_ords_prods_merged['busiest_days'] = result

# %%
# check the values of the new column 'busiest_days'

df_ords_prods_merged['busiest_days'].value_counts(dropna = False)
# Out:
# Regularly busy days    12916111
# Busiest days           11864412
# Least busy days         7624336
# Name: busiest_days, dtype: int64

# %% [markdown]
# Despite most days being regularly busy(12.916.111), Instacart has more busiest days (11.864.412) than least busy days (7.624.336).

# %% [markdown]
# * When too many users make Instacart orders at the same time, the app freezes. The senior technical officer at Instacart wants you to identify the busiest hours of the day. Rather than by hour, they want periods of time labeled “Most orders,” “Average orders,” and “Fewest orders.” Create a new column containing these labels called “busiest_period_of_day.”

# %%
# Identify the busiest hours of the day


df_ords_prods_merged['order_hour_of_day' ].value_counts (dropna = False)
# Out:
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: order_hour_of_day, dtype: int64

# %%
# label the busiest hours of the day as "Most orders", "Average orders", and "Fewest orders"

df_ords_prods_merged.loc[df_ords_prods_merged['order_hour_of_day'] >= 10, 'busiest_period_of_day'] = 'Most orders'

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['order_hour_of_day'] <= 5, 'busiest_period_of_day'] = 'Fewest orders'

# %%
df_ords_prods_merged.loc[(df_ords_prods_merged['order_hour_of_day'] > 5) & (df_ords_prods_merged['order_hour_of_day'] < 10), 'busiest_period_of_day'] = 'Average orders'

# %%
# check the values of the new column 'busiest_period_of_day'

df_ords_prods_merged['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# Most orders       26454663
# Average orders     5353868
# Fewest orders       596328
# Name: busiest_period_of_day, dtype: int64

# %% [markdown]
# # Export data

# %%
# Export df_ords_prods_merged as a pickle file

df_ords_prods_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged.pkl'))

# %%
df_ords_prods_merged.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   3139998      138            28          6                 11
# 1   1977647      138            30          6                 17
# 2    389851      709             2          0                 21
# 3    652770      764             1          3                 13
# 4   1813452      764             3          4                 17
#
#    days_since_prior_order  first_time_order  add_to_cart_order  reordered  \
# ...

# %%
df_ords_prods_merged.isnull().sum()
